# %% [markdown]
# <b>This project is made by python2.7

# %%
import preprocessing
import processing

# %% [markdown]
# <b>Read data

# %%
data = preprocessing.get_train_set()
X = preprocessing.get_X(data)
X.head()
# Out:
# preprocessing.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   X['prop_' + c] = X[c]/ X['nb_occ']
#    prop_inf_2  prop_inf_7  prop_inf_15  prop_inf_30  prop_inf_50  prop_sup_50
# 0    0.397436    0.192308     0.096154     0.102564     0.057692     0.153846
# 1    0.622642    0.018868     0.320755     0.000000     0.037736     0.000000
# 2    0.043956    0.054945     0.131868     0.285714     0.340659     0.142857
# 3    1.000000    0.000000     0.000000     0.000000     0.000000     0.000000
# 4    0.166667    0.000000     0.000000     0.333333     0.166667     0.333333

# %% [markdown]
# <b>Use GMM searching the best group numbers

# %%
idx = processing.gmm_components(X=X, threshold=2000)
X.head()
# Out:
# /Users/qixiangpeng/anaconda/lib/python2.7/site-packages/sklearn/utils/deprecation.py:52: DeprecationWarning: Class GMM is deprecated; The class GMM is deprecated in 0.18 and will be  removed in 0.20. Use class GaussianMixture instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /Users/qixiangpeng/anaconda/lib/python2.7/site-packages/sklearn/utils/deprecation.py:70: DeprecationWarning: Function distribute_covar_matrix_to_match_covariance_type is deprecated; The functon distribute_covar_matrix_to_match_covariance_typeis deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# /Users/qixiangpeng/anaconda/lib/python2.7/site-packages/sklearn/utils/deprecation.py:70: DeprecationWarning: Function log_multivariate_normal_density is deprecated; The function log_multivariate_normal_density is deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# ...

# %% [markdown]
# <b>Use GMM with 5 groups

# %%
processing.gmm_segmentation(n_component=5, X=X, data=data)
X.head()
# Out:
# /Users/qixiangpeng/anaconda/lib/python2.7/site-packages/sklearn/utils/deprecation.py:52: DeprecationWarning: Class GMM is deprecated; The class GMM is deprecated in 0.18 and will be  removed in 0.20. Use class GaussianMixture instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /Users/qixiangpeng/anaconda/lib/python2.7/site-packages/sklearn/utils/deprecation.py:70: DeprecationWarning: Function distribute_covar_matrix_to_match_covariance_type is deprecated; The functon distribute_covar_matrix_to_match_covariance_typeis deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# /Users/qixiangpeng/anaconda/lib/python2.7/site-packages/sklearn/utils/deprecation.py:70: DeprecationWarning: Function log_multivariate_normal_density is deprecated; The function log_multivariate_normal_density is deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# ...

# %% [markdown]
# <b>Use k-means

# %%
res = processing.k_means(n_clusters=5, X=X, data=data)
X.head()
# Out:
#              inf_2      inf_7     inf_15     inf_30     inf_50     sup_50  \
# classes
# 0        18.681840  13.498882  12.249844  19.273410  11.880191   9.415943
# 1        35.529646   8.925910   3.801903   2.329241   1.120090   1.006506
# 2         3.377449   3.956866  12.041939   2.904534   1.098961   0.982709
# 3         2.921903   2.255676   2.148658   2.811399   3.816109  20.836646
# 4        14.675570  21.445972   8.431221   4.644017   2.056821   1.816008
#
#            mean_jx     min_jx     max_jx     nb_occ         std    mode_nb  \
# classes
# 0        25.331096   8.024995  59.243797  85.000110  150.847425  12.916291
# 1         4.168606   0.320985  23.551439  52.713296   55.283799  21.049253
# 2        13.073316   5.037064  31.106778  24.362457   79.793477   6.034949
# 3        63.032227  28.545643  94.606123  34.790391  394.817646   6.033161
# 4         8.500104   1.543947  33.417823  53.069608   79.848384  11.195165
#
#            mode_jx
# classes
# 0        20.441964
# ...

# %% [markdown]
# <b>Comparasion

# %% [markdown]
# We can see from the results, 5 groups is adapted by GMM.
#
# Class 0 and 1 are used to buy tickets between last several minutes, which can be seen from the sum of inf_2 and inf_7.
#
# In the opposite, class 4 bought the tickets before.
#
# The result of k-means is similar with GMM. But according to the AIC, GMM is better.
